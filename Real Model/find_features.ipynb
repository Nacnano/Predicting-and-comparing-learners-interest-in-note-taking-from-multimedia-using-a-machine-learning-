# %%
import pandas as pd

features = pd.DataFrame()
for i in range(0,24,1):
    target = pd.read_excel("/home/s6207967/RE_Mask_RCNN/prob/prob2.xlsx")
    df = pd.read_csv("/home/s6207967/RE_Mask_RCNN/segmented2/df2_" + str(i+1))

    n=df.shape[0]
    
    obj_num=n
    box_area=0
    mask_area=0
    avg_score=0
    avg_x1=0
    avg_y1=0
    avg_x2=0
    avg_y2=0
    avg_width=0
    avg_height=0

    
    for j in range(n):
        tmp,x1,y1,x2,y2,score,classID,cntmask = df.iloc[j]

        box_area+=(y2-y1)*(x2-x1)/1080/1960
        mask_area+=cntmask/1080/1960
        avg_score+=score
        avg_x1+=x1
        avg_y1+=y1
        avg_x2+=x2
        avg_y2+=y2
        avg_width+=x2-x1
        avg_height+=y2-y1

    if n!=0:
        avg_score/=n
        avg_x1/=n
        avg_y1/=n
        avg_x2/=n
        avg_y2/=n
        avg_width/=n
        avg_height/=n
    else:
        avg_x1=1080/2
        avg_y1=1960/2
        avg_x2=1080/2
        avg_y2=1960/2

    tmp = pd.DataFrame([obj_num,box_area, mask_area, avg_score, avg_x1, avg_y1, avg_x2, avg_y2, avg_width, avg_height,target.probability.iloc[i]])
    tmp = tmp.transpose()
    tmp.columns = ['obj_num', 'box_area', 'mask_area', 'avg_score', 'avg_x1', 'avg_y1', 'avg_x2', 'avg_y2', 'avg_width', 'avg_height','prob']
    
    if i==0:
        features = tmp
        features.columns = ['obj_num', 'box_area', 'mask_area', 'avg_score', 'avg_x1', 'avg_y1', 'avg_x2', 'avg_y2', 'avg_width', 'avg_height','prob']
    else:
        features = features.append(tmp, ignore_index=True)
        
    print(i, tmp)
        
print(features)

features.to_csv("features2")
# Out:
# 0    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.782415   0.578185   0.875014    95.0   453.5   808.5  1395.5
#
#    avg_width  avg_height      prob
# 0      713.5       942.0  0.946429
# 1    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      4.0  0.575676   0.414928   0.866011  286.25  788.25  829.75  1302.5
#
#    avg_width  avg_height      prob
# 0      543.5      514.25  0.767857
# 2    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.377719   0.229422    0.99228   468.5   509.0  1012.0  1057.5
#
#    avg_width  avg_height      prob
# 0      543.5       548.5  0.660714
# 3    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.529724   0.309789   0.979339   469.5    93.0  1071.5   703.0
#
#    avg_width  avg_height      prob
# 0      602.0       610.0  0.571429
# 4    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.517774   0.298035   0.914305   477.5    99.0  1068.5   701.0
#
#    avg_width  avg_height      prob
# 0      591.0       602.0  0.285714
# 5    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.504662   0.244954   0.833337    92.5   658.0   812.5  1279.0
#
#    avg_width  avg_height  prob
# 0      720.0       621.0   1.0
# 6    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.388554   0.270582    0.85103   479.5  1112.5  1072.5  1576.0
#
#    avg_width  avg_height      prob
# 0      593.0       463.5  0.857143
# 7    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1      avg_x2  \
# 0      3.0  0.622337   0.403109   0.945885   395.0   392.0  995.333333
#
#    avg_y2   avg_width  avg_height   prob
# 0   996.0  600.333333       604.0  0.875
# 8    obj_num  box_area  mask_area  avg_score  avg_x1     avg_y1  avg_x2  \
# 0      3.0  1.605627    0.88861   0.936369   313.0  32.333333  1048.0
#
#         avg_y2  avg_width   avg_height      prob
# 0  1460.666667      735.0  1428.333333  0.910714
# 9    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.390035   0.231786   0.985633   464.5   503.5  1013.0  1064.0
#
#    avg_width  avg_height  prob
# 0      548.5       560.5  0.75
# 10    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  \
# 0      3.0  0.734564   0.383433   0.858247   138.0   514.0   866.0
#
#         avg_y2  avg_width  avg_height  prob
# 0  1166.666667      728.0  652.666667   1.0
# 11    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      1.0  0.586806   0.466397   0.999121     6.0   422.0  1056.0  1605.0
#
#    avg_width  avg_height      prob
# 0     1050.0      1183.0  0.892857
# 12    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.388076   0.232666   0.991496   469.0   505.5  1013.0  1058.5
#
#    avg_width  avg_height      prob
# 0      544.0       553.0  0.714286
# 13    obj_num  box_area  mask_area  avg_score      avg_x1      avg_y1  \
# 0      3.0  0.535725   0.306949   0.935014  382.666667  159.333333
#
#        avg_x2      avg_y2  avg_width  avg_height      prob
# 0  842.666667  593.666667      460.0  434.333333  0.767857
# 14    obj_num  box_area  mask_area  avg_score      avg_x1      avg_y1  \
# 0     38.0  1.029899   0.497979     0.9233  371.368421  955.473684
#
#        avg_x2       avg_y2   avg_width  avg_height      prob
# 0  674.289474  1111.842105  302.921053  156.368421  0.821429
# 15    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.471624   0.254549   0.921942    94.0   693.0   811.0  1294.0
#
#    avg_width  avg_height  prob
# 0      717.0       601.0   1.0
# 16    obj_num  box_area  mask_area  avg_score      avg_x1      avg_y1  avg_x2  \
# 0      3.0   0.62058   0.402073   0.909424  394.666667  388.666667   988.0
#
#        avg_y2   avg_width  avg_height      prob
# 0  993.333333  593.333333  604.666667  0.839286
# 17    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      5.0  0.721079   0.476092   0.927566   642.0   345.8  1031.4   796.6
#
#    avg_width  avg_height      prob
# 0      389.4       450.8  0.892857
# 18    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.530779   0.306385   0.977271   475.0    92.5  1069.5   706.0
#
#    avg_width  avg_height      prob
# 0      594.5       613.5  0.517857
# 19    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.478147   0.293765   0.911064   149.0   500.0   808.5  1170.5
#
#    avg_width  avg_height      prob
# 0      659.5       670.5  0.946429
# 20    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      4.0  0.876255   0.491083   0.948464   516.0   770.5   942.5  1674.0
#
#    avg_width  avg_height      prob
# 0      426.5       903.5  0.732143
# 21    obj_num  box_area  mask_area  avg_score  avg_x1  avg_y1  avg_x2  avg_y2  \
# 0      2.0  0.678216   0.336128   0.859656    41.5    54.0  1011.0   797.0
#
#    avg_width  avg_height      prob
# 0      969.5       743.0  0.642857
# 22    obj_num  box_area  mask_area  avg_score      avg_x1  avg_y1  avg_x2  \
# 0      3.0   0.56401   0.313721   0.914576  389.333333   139.0   845.0
#
#    avg_y2   avg_width  avg_height      prob
# 0   581.0  455.666667       442.0  0.392857
# 23    obj_num  box_area  mask_area  avg_score  avg_x1      avg_y1      avg_x2  \
# 0      3.0  0.640678   0.407389   0.908617   384.0  392.666667  996.666667
#
#    avg_y2   avg_width  avg_height      prob
# 0   998.0  612.666667  605.333333  0.571429
#     obj_num  box_area  mask_area  avg_score      avg_x1       avg_y1  \
# 0       2.0  0.782415   0.578185   0.875014   95.000000   453.500000
features2 = pd.read_csv('features2')

features3 = features1
features3 = features3.append(features2, ignore_index=True)
print(features3)
features3.to_csv("features3")
# Out:
#     Unnamed: 0  obj_num  box_area  mask_area  avg_score       avg_x1  \
# 0            0      1.0  0.914600   0.874060   0.982490     0.000000
# 1            1      2.0  0.081675   0.056096   0.777389   446.000000
# 2            2      0.0  0.000000   0.000000   0.000000   540.000000
# 3            3      4.0  0.108214   0.074081   0.846622   324.000000
# 4            4      3.0  0.021978   0.015675   0.860186   141.333333
# 5            5      0.0  0.000000   0.000000   0.000000   540.000000
# 6            6      1.0  0.792177   0.662684   0.740095     0.000000
# 7            7      2.0  0.008362   0.005723   0.755230  1005.000000
# 8            8      1.0  0.336333   0.180630   0.997563    42.000000
# 9            9      0.0  0.000000   0.000000   0.000000   540.000000
# 10          10      1.0  0.384776   0.283138   0.840630   111.000000
# 11          11      2.0  0.147523   0.081105   0.999272   476.500000
# 12          12     13.0  0.801075   0.504616   0.906094   317.307692
# 13          13     15.0  1.015929   0.464842   0.903396   200.133333
# 14          14      1.0  0.002328   0.001628   0.856244   943.000000
# 15          15      0.0  0.000000   0.000000   0.000000   540.000000
# 16          16      2.0  0.580952   0.281732   0.914767   184.000000
# 17          17      3.0  0.047395   0.026292   0.845929   566.333333
# 18          18      2.0  0.059208   0.027775   0.914556   467.000000
# 19          19      3.0  1.031106   0.570317   0.956914   299.666667
# 20          20     57.0  0.246405   0.132522   0.913320   604.982456
# 21           0      2.0  0.782415   0.578185   0.875014    95.000000
# 22           1      4.0  0.575676   0.414928   0.866011   286.250000
# 23           2      2.0  0.377719   0.229422   0.992280   468.500000
# 24           3      2.0  0.529724   0.309789   0.979339   469.500000
# 25           4      2.0  0.517774   0.298035   0.914305   477.500000
# 26           5      2.0  0.504662   0.244954   0.833337    92.500000
# 27           6      2.0  0.388554   0.270582   0.851030   479.500000
# 28           7      3.0  0.622337   0.403109   0.945885   395.000000
# 29           8      3.0  1.605627   0.888610   0.936369   313.000000
# 30           9      2.0  0.390035   0.231786   0.985633   464.500000
# 31          10      3.0  0.734564   0.383433   0.858247   138.000000
# 32          11      1.0  0.586806   0.466397   0.999121     6.000000
# 33          12      2.0  0.388076   0.232666   0.991496   469.000000
# 34          13      3.0  0.535725   0.306949   0.935014   382.666667
# 35          14     38.0  1.029899   0.497979   0.923300   371.368421
# 36          15      2.0  0.471624   0.254549   0.921942    94.000000
# 37          16      3.0  0.620580   0.402073   0.909424   394.666667
# 38          17      5.0  0.721079   0.476092   0.927566   642.000000
# 39          18      2.0  0.530779   0.306385   0.977271   475.000000
# 40          19      2.0  0.478147   0.293765   0.911064   149.000000
# 41          20      4.0  0.876255   0.491083   0.948464   516.000000
# 42          21      2.0  0.678216   0.336128   0.859656    41.500000
# 43          22      3.0  0.564010   0.313721   0.914576   389.333333
# 44          23      3.0  0.640678   0.407389   0.908617   384.000000
#
#          avg_y1       avg_x2       avg_y2    avg_width   avg_height      prob
# 0     17.000000  1062.000000  1840.000000  1062.000000  1823.000000  0.879310
